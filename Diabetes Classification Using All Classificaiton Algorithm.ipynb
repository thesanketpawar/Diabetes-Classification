# %% [markdown]
# Problem Statement: Diabetes Classification using Machine Learning
#
# Context:
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. All patients here are females at least 21 years old of Pima Indian heritage.
#
# The datasets consist of several medical predictor variables and one target variable, Outcome. Predictor variables include the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/diabetes.csv')

# %%
data.head()

# %%
x=data.drop(['Outcome'],axis=1)
y=data['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
forest_classifier=RandomForestClassifier()

# %%
forest_classifier.fit(x_train,y_train)

# %%
y_pred=forest_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
print(cm)

# %%
print(ac)

# %%
new_data={'Pregnancies':6 ,'Glucose':250,	'BloodPressure':100, 'SkinThickness':28,	'Insulin':500, 'BMI':53.6, 'DiabetesPedigreeFunction':0.187, 'Age':32}

# %%
print(new_data)

# %%
index=[1]
my_data=pd.DataFrame(new_data,index)

# %%
print(my_data)

# %%
y_pred=forest_classifier.predict(my_data)

# %%
if  y_pred==0:
  print("The Patient is Not Diabetic in nature",y_pred)

else:
  print("The Patient is Diabetic in nature",y_pred)

# %% [markdown]
# DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier
tree_classifier=DecisionTreeClassifier()

# %%
tree_classifier.fit(x_train,y_train)

# %%
a_pred=tree_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,a_pred)
ac=accuracy_score(y_test,a_pred)

# %%
print(cm)

# %%
print(ac)
# Out:
# 0.7012987012987013

# %%
new_data={'Pregnancies':2 ,'Glucose':100,	'BloodPressure':40, 'SkinThickness':20,	'Insulin':0, 'BMI':23.6, 'DiabetesPedigreeFunction':0.117, 'Age':22}

# %%
index=[1]
my_data=pd.DataFrame(new_data,index)
print(my_data)

# %%
a_pred=tree_classifier.predict(my_data)

# %%
if  a_pred==0:
  print("The Patient is Not Diabetic in nature",a_pred)

else:
  print("The Patient is Diabetic in nature",a_pred)

# %% [markdown]
# USING LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()

# %%
log_model.fit(x_train,y_train)

# %%
log_pred=log_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,log_pred)
ac=accuracy_score(y_test,log_pred)

# %%
print(cm)

# %%
print(ac)

# %%
new_data={'Pregnancies':2 ,'Glucose':580,	'BloodPressure':240, 'SkinThickness':20,	'Insulin':700, 'BMI':53.6, 'DiabetesPedigreeFunction':0.195, 'Age':42}

# %%
index=[1]
my_data=pd.DataFrame(new_data,index)
print(my_data)

# %%
log_pred=log_model.predict(my_data)

# %%
if  log_pred==0:
  print("The Patient is Not Diabetic in nature",log_pred)

else:
  print("The Patient is Diabetic in nature",log_pred)

# %% [markdown]
# USING KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier(n_neighbors=5)

# %%
knn_classifier.fit(x_train,y_train)

# %%
knn_pred=knn_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,knn_pred)
ac=accuracy_score(y_test,knn_pred)

# %%
print(cm)

# %%
print(ac)

# %%
new_data={'Pregnancies':2 ,'Glucose':80,	'BloodPressure':20, 'SkinThickness':20,	'Insulin':0, 'BMI':23.6, 'DiabetesPedigreeFunction':0.195, 'Age':42}

# %%
index=[1]
my_data=pd.DataFrame(new_data,index)
print(my_data)

# %%
knn_pred=knn_classifier.predict(my_data)

# %%
if  knn_pred==0:
  print("The Patient is Not Diabetic in nature",knn_pred)

else:
  print("The Patient is Not Diabetic in nature",knn_pred)
# Out:
# The Patient is Not Diabetic in nature [0]
